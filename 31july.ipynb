# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from openai import OpenAI
openai = OpenAI()

# %%
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr 
import json

# %%
reader = PdfReader("Vedant_Shekhar_Resume_ATS.pdf")
whole_texts = ""
for page in reader.pages:
    texts = page.extract_text()
    if(texts):
        whole_texts += texts

# %%
print(whole_texts)
# Out:
# VEDANT SHEKHAR
#  Rajkot, Gujarat, India | +91-9157827489 | vedantshekharb1@gmail.com | LinkedIn | GitHub | LeetCode
# PROFESSIONAL SUMMARY
# Computer Engineering undergraduate (CGPA 9.47/10, Top 1%) specializing in Artificial Intelligence at Marwadi University.
# Hands-on production experience in Generative AI, Machine Learning, Deep Learning, and Transformer architectures. Strong
# software engineering foundation in C++ and Python with 500+ DSA problems solved. Published patent holder as a 2nd-year
# undergraduate.
# EDUCATION
# B.Tech in Computer Engineering — Artificial Intelligence        Expected May 2027
# Marwadi University, Rajkot, India | CGPA: 9.47 / 10 (Top 1% of cohort)
# TECHNICAL SKILLS
# Programming Languages: C, C++, Python, JavaScript, Java, Swift, SQL
# AI / ML Frameworks: TensorFlow, Keras, PyTorch, LangChain, Hugging Face Transformers, Gemini API, OpenAI API
# GenAI & RAG: Retrieval-Augmented Generation (RAG), Vector Databases (Pinecone), Prompt Engineering, Embeddings, LLM
# Fine-tuning
# Backend & Tools: Node.js, REST APIs, Firebase (FCM), Git, GitHub, Linux, Streamlit, VS Code API
# Mobile Development: Kotlin, Jetpack Compose, Wear OS, Android SDK
# Security: JWT, AES-256, SSL Certificate Pinning, OWASP Mobile Top 10
# CS Fundamentals: Data Structures & Algorithms (DSA), OOP, DBMS, System Design, Computer Vision
# EXPERIENCE
# Software Engineer Intern | Uest EdTech Pvt. Ltd., Rajkot
# May 2026 – Present
#  Designed and built a Wear OS smartwatch module (Kotlin, Jetpack Compose) for a School ERP platform serving 3,000+
#  students across 12 schools, enabling real-time access to student/staff directories, admissions, fee records, and leave
# approvals.
#  Developed and integrated 10+ backend REST APIs within the first month for watch-specific workflows including student/staff
#  listing, leave approval, admissions, and ERP dashboard metrics; restructured database schemas to align with production ERP
# data.
#  Implemented Firebase Cloud Messaging (FCM) for real-time push notifications — device token registration, backend sync,
#  and instant alerts for admissions, leave requests, and school events.
#  Enhanced Wear OS UX using Jetpack Compose components, Swipe-to-Go-Back navigation, and dark theme optimization;
#  reduced wrist-based ERP interaction time and improved overall responsiveness.
# Technical Lead | Marwadi University AI/ML Club, Rajkot
# Jan 2024 – Present
#  Led an 8-member team delivering AI/ML projects at university hackathons; organized hands-on GenAI workshops covering
#  LangChain and Hugging Face, attended by 100+ students.
#  Mentored junior members on NLP, computer vision, and LLM-based project architectures; drove adoption of best practices in
#  model training and deployment.
# Competitive Programmer | LeetCode / STRIKE Platform
# 2023 – Present
#  Solved 500+ DSA problems in C++ across arrays, trees, graphs, dynamic programming, and greedy algorithms; consistently
#  ranked in the top percentile on contest leaderboards.
# PROJECTS
# ASHA AI Assistant — GenAI Healthcare Platform for Rural India | Node.js, Gemini API, RAG, Pinecone | GitHub
#  Built a 16-feature AI assistant for rural ASHA healthcare workers featuring real-time triage scoring (0–100), a RAG pipeline
#  using Google text-embedding-004 with cosine similarity retrieval over a Pinecone vector store.
#  Integrated Gemini Vision for image-based diagnosis, bilingual Hindi/English voice support, and live RSS-based disease
#  outbreak trend detection.
# Plant Disease Detection System | Python, TensorFlow, Keras, InceptionV3, Streamlit
#  Trained CNN and InceptionV3 models on 56,000+ images across 38 crop disease classes; achieved 91.5% test accuracy via
#  transfer learning and data augmentation.
#  Deployed Streamlit web app with Class Activation Maps (CAM) for explainable AI, enabling farmers to identify and act on crop
#  diseases with visual explanations.
# CodeCritic — GenAI-Powered VS Code Extension | JavaScript, VS Code API, Gemini API | GitHub
#  Developed a GenAI VS Code extension for multi-file static analysis and automated code refactoring; implemented
#  context-aware prompt engineering to deliver actionable, real-time in-editor diagnostics.
# ACHIEVEMENTS & PATENT
# Patent Filed — AI-Powered Nutritional Prep Unit (Ref. No. MU.1956)
#  Filed patent for an IoT-based automated meal preparation device combining embedded sensors, computer vision (AWS
#  Rekognition), and AI-driven nutritional analysis — a rare achievement as a 2nd-year undergraduate.
# Academic Excellence: CGPA 9.47/10 — consistently top 1% of B.Tech cohort across all semesters.

# %%
model_name = "gpt-4o-mini"

# %%
system_prompt = f""" 

#Your Role:

ok so your vedant's personal assistant named "Vedant4857" who will help people who want to know about vedant who has access to my resume : {whole_texts}
form this you are supposed to answer questions form ,
undertsnad the question asked refer my resume understand teh similarity and context and then answer answer on basis of that. 
Dont go too big answer only neccessary and good amount.

#Rules:

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))
# Out:
#
#
# #Your Role:
#
# ok so your vedant's personal assistant named "Vedant4857" who will help people who want to know about vedant who has access to my resume : VEDANT SHEKHAR
#  Rajkot, Gujarat, India | +91-9157827489 | vedantshekharb1@gmail.com | LinkedIn | GitHub | LeetCode
# PROFESSIONAL SUMMARY
# Computer Engineering undergraduate (CGPA 9.47/10, Top 1%) specializing in Artificial Intelligence at Marwadi University.
# Hands-on production experience in Generative AI, Machine Learning, Deep Learning, and Transformer architectures. Strong
# software engineering foundation in C++ and Python with 500+ DSA problems solved. Published patent holder as a 2nd-year
# undergraduate.
# EDUCATION
# B.Tech in Computer Engineering — Artificial Intelligence        Expected May 2027
# Marwadi University, Rajkot, India | CGPA: 9.47 / 10 (Top 1% of cohort)
# TECHNICAL SKILLS
# Programming Languages: C, C++, Python, JavaScript, Java, Swift, SQL
# AI / ML Frameworks: TensorFlow, Keras, PyTorch, LangChain, Hugging Face Transformers, Gemini API, OpenAI API
# GenAI & RAG: Retrieval-Augmented Generation (RAG), Vector Databases (Pinecone), Prompt Engineering, Embeddings, LLM
# Fine-tuning
# Backend & Tools: Node.js, REST APIs, Firebase (FCM), Git, GitHub, Linux, Streamlit, VS Code API
# Mobile Development: Kotlin, Jetpack Compose, Wear OS, Android SDK
# Security: JWT, AES-256, SSL Certificate Pinning, OWASP Mobile Top 10
# CS Fundamentals: Data Structures & Algorithms (DSA), OOP, DBMS, System Design, Computer Vision
# EXPERIENCE
# Software Engineer Intern | Uest EdTech Pvt. Ltd., Rajkot
# May 2026 – Present
#  Designed and built a Wear OS smartwatch module (Kotlin, Jetpack Compose) for a School ERP platform serving 3,000+
#  students across 12 schools, enabling real-time access to student/staff directories, admissions, fee records, and leave
# approvals.
#  Developed and integrated 10+ backend REST APIs within the first month for watch-specific workflows including student/staff
#  listing, leave approval, admissions, and ERP dashboard metrics; restructured database schemas to align with production ERP
# data.
#  Implemented Firebase Cloud Messaging (FCM) for real-time push notifications — device token registration, backend sync,
#  and instant alerts for admissions, leave requests, and school events.
#  Enhanced Wear OS UX using Jetpack Compose components, Swipe-to-Go-Back navigation, and dark theme optimization;
#  reduced wrist-based ERP interaction time and improved overall responsiveness.
# Technical Lead | Marwadi University AI/ML Club, Rajkot
# Jan 2024 – Present
#  Led an 8-member team delivering AI/ML projects at university hackathons; organized hands-on GenAI workshops covering
#  LangChain and Hugging Face, attended by 100+ students.
#  Mentored junior members on NLP, computer vision, and LLM-based project architectures; drove adoption of best practices in
#  model training and deployment.
# Competitive Programmer | LeetCode / STRIKE Platform
# 2023 – Present
#  Solved 500+ DSA problems in C++ across arrays, trees, graphs, dynamic programming, and greedy algorithms; consistently
#  ranked in the top percentile on contest leaderboards.
# PROJECTS
# ASHA AI Assistant — GenAI Healthcare Platform for Rural India | Node.js, Gemini API, RAG, Pinecone | GitHub
#  Built a 16-feature AI assistant for rural ASHA healthcare workers featuring real-time triage scoring (0–100), a RAG pipeline
#  using Google text-embedding-004 with cosine similarity retrieval over a Pinecone vector store.
#  Integrated Gemini Vision for image-based diagnosis, bilingual Hindi/English voice support, and live RSS-based disease
#  outbreak trend detection.
# Plant Disease Detection System | Python, TensorFlow, Keras, InceptionV3, Streamlit
#  Trained CNN and InceptionV3 models on 56,000+ images across 38 crop disease classes; achieved 91.5% test accuracy via
#  transfer learning and data augmentation.
#  Deployed Streamlit web app with Class Activation Maps (CAM) for explainable AI, enabling farmers to identify and act on crop
#  diseases with visual explanations.
# CodeCritic — GenAI-Powered VS Code Extension | JavaScript, VS Code API, Gemini API | GitHub
#  Developed a GenAI VS Code extension for multi-file static analysis and automated code refactoring; implemented
#  context-aware prompt engineering to deliver actionable, real-time in-editor diagnostics.
# ACHIEVEMENTS & PATENT
# Patent Filed — AI-Powered Nutritional Prep Unit (Ref. No. MU.1956)
#  Filed patent for an IoT-based automated meal preparation device combining embedded sensors, computer vision (AWS
#  Rekognition), and AI-driven nutritional analysis — a rare achievement as a 2nd-year undergraduate.
# Academic Excellence: CGPA 9.47/10 — consistently top 1% of B.Tech cohort across all semesters.
#
# form this you are supposed to answer questions form ,
# undertsnad the question asked refer my resume understand teh similarity and context and then answer answer on basis of that.
# Dont go too big answer only neccessary and good amount.
#
# #Rules:
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Avoid answering questions that are not related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role":"system","content":system_prompt},
    {"role":"user","content":"List projects done by you"}
]

# %%
response = openai.chat.completions.create(model=model_name,messages=messages)
answer = response.choices[0].message.content
display(Markdown(answer))
# Out:
# Here are some of the key projects I've worked on:
#
# 1. **ASHA AI Assistant — GenAI Healthcare Platform for Rural India**
#    - Developed a 16-feature AI assistant for rural ASHA healthcare workers, implementing real-time triage scoring and a Retrieval-Augmented Generation (RAG) pipeline using Google text-embedding-004 with cosine similarity retrieval over a Pinecone vector store.
#    - Integrated image-based diagnosis using Gemini Vision and provided bilingual voice support along with live disease outbreak trend detection.
#
# 2. **Plant Disease Detection System**
#    - Created a model trained on over 56,000 images across 38 crop disease classes using Python, TensorFlow, and Keras to achieve 91.5% test accuracy through transfer learning and data augmentation.
#    - Deployed a Streamlit web app featuring Class Activation Maps (CAM) for explainable AI, assisting farmers in identifying and acting on crop diseases visually.
#
# 3. **CodeCritic — GenAI-Powered VS Code Extension**
#    - Developed a VS Code extension for multi-file static analysis and automated code refactoring, implementing context-aware prompt engineering for real-time in-editor diagnostics.
#
# If you'd like more details about any specific project, feel free to ask!

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=model_name, messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model=model_name, messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called to record an email: crazy@gmail.com
